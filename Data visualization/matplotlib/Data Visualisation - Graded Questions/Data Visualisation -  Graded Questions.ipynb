# %% [markdown]
# ## Data Visualisation - Graded Questions

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
#Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
df1 = pd.read_csv("Marks.csv")

# %%
df1.head(30)
# Out:
#     Score A  Score B  Score C  Score D
# 0     230.1     37.8     69.2     22.1
# 1      44.5     39.3     45.1     10.4
# 2      17.2     45.9     69.3     12.0
# 3     151.5     41.3     58.5     16.5
# 4     180.8     10.8     58.4     17.9
# 5       8.7     48.9     75.0      7.2
# 6      57.5     32.8     23.5     11.8
# 7     120.2     19.6     11.6     13.2
# 8       8.6      2.1      1.0      4.8
# 9     199.8      2.6     21.2     15.6
# 10     66.1      5.8     24.2     12.6
# 11    214.7     24.0      4.0     17.4
# 12     23.8     35.1     65.9      9.2
# 13     97.5      7.6      7.2     13.7
# 14    204.1     32.9     46.0     19.0
# 15    195.4     47.7     52.9     22.4
# 16     67.8     36.6    114.0     12.5
# 17    281.4     39.6     55.8     24.4
# 18     69.2     20.5     18.3     11.3
# 19    147.3     23.9     19.1     14.6
# 20    218.4     27.7     53.4     18.0
# 21    237.4      5.1     23.5     17.5
# 22     13.2     15.9     49.6      5.6
# 23    228.3     16.9     26.2     20.5
# 24     62.3     12.6     18.3      9.7
# 25    262.9      3.5     19.5     17.0
# 26    142.9     29.3     12.6     15.0
# 27    240.1     16.7     22.9     20.9
# 28    248.8     27.1     22.9     18.9
# 29     70.6     16.0     40.8     10.5

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250

# %%
#Your code here

plt.hist(df1["Score A"],bins=6)
plt.show()

# %%
sns.boxplot(df1["Score C"])
plt.show()

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C

# %%
#Your code here

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
#Load the dataset
df2 =pd.read_csv("superstore.csv")

# %%
df3= df2.groupby("Ship Mode").agg({'Quantity':np.sum})
# Out:
# C:\Users\suddkar\AppData\Local\Temp\ipykernel_15036\787867948.py:1: FutureWarning: The provided callable <function sum at 0x0000012D7B72E0C0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df3= df2.groupby("Ship Mode").agg({'Quantity':np.sum})

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
#Your code here

df3
# Out:
#                 Quantity
# Ship Mode
# First Class         5693
# Same Day            1960
# Second Class        7423
# Standard Class     22797

# %%
df2["Ship Mode"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df2
# Out:
#             Order ID       Ship Mode    Segment Region       Product ID  \
# 0     CA-2016-152156    Second Class   Consumer  South  FUR-BO-10001798
# 1     CA-2016-152156    Second Class   Consumer  South  FUR-CH-10000454
# 2     CA-2016-138688    Second Class  Corporate   West  OFF-LA-10000240
# 3     US-2015-108966  Standard Class   Consumer  South  FUR-TA-10000577
# 4     US-2015-108966  Standard Class   Consumer  South  OFF-ST-10000760
# ...              ...             ...        ...    ...              ...
# 9989  CA-2014-110422    Second Class   Consumer  South  FUR-FU-10001889
# 9990  CA-2017-121258  Standard Class   Consumer   West  FUR-FU-10000747
# 9991  CA-2017-121258  Standard Class   Consumer   West  TEC-PH-10003645
# 9992  CA-2017-121258  Standard Class   Consumer   West  OFF-PA-10004041
# 9993  CA-2017-119914    Second Class   Consumer   West  OFF-AP-10002684
#
#          Sales  Quantity Discount    Profit
# 0     261.9600         2       0%   41.9136
# 1     731.9400         3       0%  219.5820
# 2      14.6200         2       0%    6.8714
# 3     957.5775         5    0.45% -383.0310
# 4      22.3680         2    0.20%    2.5164
# ...        ...       ...      ...       ...
# 9989   25.2480         3    0.20%    4.1028
# 9990   91.9600         2       0%   15.6332
# 9991  258.5760         2    0.20%   19.3932
# 9992   29.6000         4       0%   13.3200
# 9993  243.1600         2       0%   72.9480
#
# [9994 rows x 9 columns]

# %%
df2["Discount"]=df2["Discount"].str.replace('%','')
df2["Discount"]=df2["Discount"].astype(float)

# %%
df2.groupby("Region").agg({'Discount':np.mean})
# Out:
# C:\Users\suddkar\AppData\Local\Temp\ipykernel_15036\399553193.py:1: FutureWarning: The provided callable <function mean at 0x0000012D7B72F1A0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df2.groupby("Region").agg({'Discount':np.mean})
#          Discount
# Region
# Central  0.240353
# East     0.145365
# South    0.147253
# West     0.109335

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central
#     b)South
#     c)West
#     d)East

# %%
#Your code here
