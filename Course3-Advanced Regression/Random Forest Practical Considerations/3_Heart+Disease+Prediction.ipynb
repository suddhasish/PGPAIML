2 MB/s eta 0:00:01
#    ----------------------- ---------------- 25.8/44.8 MB 38.5 MB/s eta 0:00:01
#    ------------------------ --------------- 27.2/44.8 MB 40.9 MB/s eta 0:00:01
#    ------------------------ --------------- 27.8/44.8 MB 40.9 MB/s eta 0:00:01
#    ------------------------ --------------- 27.8/44.8 MB 40.9 MB/s eta 0:00:01
#    ------------------------- -------------- 28.5/44.8 MB 27.3 MB/s eta 0:00:01
#    --------------------------- ------------ 31.0/44.8 MB 29.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 32.9/44.8 MB 28.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 33.3/44.8 MB 26.2 MB/s eta 0:00:01
#    ------------------------------ --------- 34.1/44.8 MB 25.2 MB/s eta 0:00:01
#    ------------------------------- -------- 35.6/44.8 MB 23.4 MB/s eta 0:00:01
#    -------------------------------- ------- 36.1/44.8 MB 21.8 MB/s eta 0:00:01
#    --------------------------------- ------ 37.2/44.8 MB 21.1 MB/s eta 0:00:01
#    --------------------------------- ------ 37.9/44.8 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.2/44.8 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.2/44.8 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.8/44.8 MB 19.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.2/44.8 MB 17.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.6/44.8 MB 16.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.6/44.8 MB 16.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.2/44.8 MB 14.6 MB/s eta 0:00:01
#    ------------------------------------ --- 40.4/44.8 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------ --- 40.6/44.8 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ --- 40.7/44.8 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------ --- 41.0/44.8 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 41.0/44.8 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 41.2/44.8 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 41.3/44.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 41.4/44.8 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------ --- 41.4/44.8 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 41.5/44.8 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------- -- 41.6/44.8 MB 9.1 MB/s eta 0:00:01
#    ------------------------------------- -- 41.7/44.8 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------- -- 41.8/44.8 MB 8.1 MB/s eta 0:00:01
#    ------------------------------------- -- 41.9/44.8 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 42.0/44.8 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------- -- 42.1/44.8 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 42.2/44.8 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------- -- 42.3/44.8 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 42.4/44.8 MB 6.6 MB/s eta 0:00:01
#    ------------------------------------- -- 42.5/44.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 42.6/44.8 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 42.7/44.8 MB 6.0 MB/s eta 0:00:01
#    -------------------------------------- - 42.8/44.8 MB 5.9 MB/s eta 0:00:01
#    -------------------------------------- - 42.9/44.8 MB 5.7 MB/s eta 0:00:01
#    -------------------------------------- - 43.0/44.8 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 43.1/44.8 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 43.2/44.8 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 43.3/44.8 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 43.4/44.8 MB 5.2 MB/s eta 0:00:01
#    -------------------------------------- - 43.5/44.8 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 43.6/44.8 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  43.7/44.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.8 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  43.9/44.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  44.2/44.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  44.4/44.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  44.6/44.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 3.8 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\suddkar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Reading the csv file and putting it into 'df' object.
df = pd.read_csv('heart_v2.csv')

# %%
df.columns
# Out:
# Index(['age', 'sex', 'BP', 'cholestrol', 'heart disease'], dtype='object')

# %%
df.head()
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   70    1  130         322              1
# 1   67    0  115         564              0
# 2   57    1  124         261              1
# 3   64    1  128         263              0
# 4   74    0  120         269              0

# %%
# Putting feature variable to X
X = df.drop('heart disease',axis=1)

# Putting response variable to y
y = df['heart disease']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((189, 4), (81, 4))

# %% [markdown]
# Fitting the decision tree with default hyperparameters, apart from max_depth which is 3 so that we can plot and read the tree.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
#!pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    ----------------- ---------------------- 20.5/47.1 kB 682.7 kB/s eta 0:00:01
#    ---------------------------------- ----- 41.0/47.1 kB 495.5 kB/s eta 0:00:01
#    ---------------------------------------- 47.1/47.1 kB 396.6 kB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\suddkar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#!pip install pydotplus
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      ---------------------------------------- 0.0/278.7 kB ? eta -:--:--
#      - -------------------------------------- 10.2/278.7 kB ? eta -:--:--
#      - -------------------------------------- 10.2/278.7 kB ? eta -:--:--
#      ----- ------------------------------- 41.0/278.7 kB 281.8 kB/s eta 0:00:01
#      ---------- -------------------------- 81.9/278.7 kB 512.0 kB/s eta 0:00:01
#      ------------------------- ---------- 194.6/278.7 kB 985.7 kB/s eta 0:00:01
#      -------------------------------------- 278.7/278.7 kB 1.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pyparsing>=2.0.1 (from pydotplus)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
#    ---------------------------------------- 0.0/106.9 kB ? eta -:--:--
#    ---------------------------------------- 106.9/106.9 kB 3.1 MB/s eta 0:00:00
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (pyproject.toml): started
#   Building wheel for pydotplus (pyproject.toml): finished with status 'done'
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24574 sha256=074c59d4ce0114495425fdc690483155f7982ee19fd6c80ab71562a199e21642
#   Stored in directory: c:\users\suddkar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\bd\ce\e8\ff9d9c699514922f57caa22fbd55b0a32761114b4c4acc9e03
# Successfully built pydotplus
# Installing collected packages: pyparsing, pydotplus
# Successfully installed pydotplus-2.0.2 pyparsing-3.2.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\suddkar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install six
# Out:
# Requirement already satisfied: six in c:\users\suddkar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\suddkar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Importing required packages for visualization
from IPython.display import Image  
from six import StringIO  
from sklearn.tree import export_graphviz
import pydotplus, graphviz

# %%
# plotting tree with max_depth=3
dot_data = StringIO()  

export_graphviz(dt, out_file=dot_data, filled=True, rounded=True,
                feature_names=X.columns, 
                class_names=['No Disease', "Disease"])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
#Image(graph.create_png(),width=800,height=900)
#graph.write_pdf("dt_heartdisease.pdf")

# %% [markdown]
# #### Evaluating model performance

# %%
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
print(accuracy_score(y_train, y_train_pred))
confusion_matrix(y_train, y_train_pred)
# Out:
# 0.7407407407407407
# array([[82, 19],
#        [30, 58]])

# %%
print(accuracy_score(y_test, y_test_pred))
confusion_matrix(y_test, y_test_pred)
# Out:
# 0.6049382716049383
# array([[35, 14],
#        [18, 14]])

# %% [markdown]
# Creating helper functions to evaluate model performance and help plot the decision tree

# %%
def get_dt_graph(dt_classifier):
    dot_data = StringIO()
    export_graphviz(dt_classifier, out_file=dot_data, filled=True,rounded=True,
                    feature_names=X.columns, 
                    class_names=['Disease', "No Disease"])
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    return graph

# %%
def evaluate_model(dt_classifier):
    print("Train Accuracy :", accuracy_score(y_train, dt_classifier.predict(X_train)))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, dt_classifier.predict(X_train)))
    print("-"*50)
    print("Test Accuracy :", accuracy_score(y_test, dt_classifier.predict(X_test)))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, dt_classifier.predict(X_test)))

# %% [markdown]
# ### Without setting any hyper-parameters

# %%
dt_default = DecisionTreeClassifier(random_state=42)
dt_default.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
gph = get_dt_graph(dt_default)
Image(gph.create_png())

# %%
evaluate_model(dt_default)
# Out:
# Train Accuracy : 1.0
# Train Confusion Matrix:
# [[101   0]
#  [  0  88]]
# --------------------------------------------------
# Test Accuracy : 0.6296296296296297
# Test Confusion Matrix:
# [[31 18]
#  [12 20]]

# %% [markdown]
# ### Controlling the depth of the tree

# %%
# ?DecisionTreeClassifier

# %%
dt_depth = DecisionTreeClassifier(max_depth=3)
dt_depth.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
gph = get_dt_graph(dt_depth) 
Image(gph.create_png())

# %%
evaluate_model(dt_depth)
# Out:
# Train Accuracy : 0.7407407407407407
# Train Confusion Matrix:
# [[82 19]
#  [30 58]]
# --------------------------------------------------
# Test Accuracy : 0.6049382716049383
# Test Confusion Matrix:
# [[35 14]
#  [18 14]]

# %% [markdown]
# ### Specifying minimum samples before split

# %%
dt_min_split = DecisionTreeClassifier(min_samples_split=20)
dt_min_split.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=20)

# %%
gph = get_dt_graph(dt_min_split) 
Image(gph.create_png())

# %%
evaluate_model(dt_min_split)
# Out:
# Train Accuracy : 0.8359788359788359
# Train Confusion Matrix:
# [[85 16]
#  [15 73]]
# --------------------------------------------------
# Test Accuracy : 0.6419753086419753
# Test Confusion Matrix:
# [[32 17]
#  [12 20]]

# %% [markdown]
# ### Specifying minimum samples in leaf node

# %%
dt_min_leaf = DecisionTreeClassifier(min_samples_leaf=20, random_state=42)
dt_min_leaf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=20, random_state=42)

# %%
gph = get_dt_graph(dt_min_leaf)
Image(gph.create_png())

# %%
evaluate_model(dt_min_leaf)
# Out:
# Train Accuracy : 0.7037037037037037
# Train Confusion Matrix:
# [[85 16]
#  [40 48]]
# --------------------------------------------------
# Test Accuracy : 0.6419753086419753
# Test Confusion Matrix:
# [[38 11]
#  [18 14]]

# %% [markdown]
# ### Using Entropy instead of Gini

# %%
dt_min_leaf_entropy = DecisionTreeClassifier(min_samples_leaf=20, random_state=42, criterion="entropy")
dt_min_leaf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_leaf=20,
#                        random_state=42)

# %%
gph = get_dt_graph(dt_min_leaf_entropy)
Image(gph.create_png())

# %%
evaluate_model(dt_min_leaf_entropy)
# Out:
# Train Accuracy : 0.7037037037037037
# Train Confusion Matrix:
# [[85 16]
#  [40 48]]
# --------------------------------------------------
# Test Accuracy : 0.6419753086419753
# Test Confusion Matrix:
# [[38 11]
#  [18 14]]

# %% [markdown]
# ### Hyper-parameter tuning

# %%
dt = DecisionTreeClassifier(random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Create the parameter grid based on the results of random search 
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
# grid_search = GridSearchCV(estimator=dt, 
#                            param_grid=params, 
#                            cv=4, n_jobs=-1, verbose=1, scoring = "f1")

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=dt, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
# %%time
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# CPU times: total: 1.75 s
# Wall time: 12.1 s
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
score_df = pd.DataFrame(grid_search.cv_results_)
score_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.016199      0.010050         0.010226        0.006029
# 1       0.011813      0.008733         0.007299        0.005130
# 2       0.007143      0.004189         0.004668        0.003943
# 3       0.007917      0.003090         0.005772        0.009998
# 4       0.009309      0.005567         0.009836        0.001992
#
#   param_criterion  param_max_depth  param_min_samples_leaf  \
# 0            gini                2                       5
# 1            gini                2                      10
# 2            gini                2                      20
# 3            gini                2                      50
# 4            gini                2                     100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.708333
# 1  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.708333
# 2  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.687500
# 3  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.666667
# 4  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.541667
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.744681           0.617021           0.531915         0.650488
# 1           0.744681           0.617021           0.531915         0.650488
# 2           0.744681           0.617021           0.531915         0.645279
# 3           0.680851           0.574468           0.702128         0.656028
# 4           0.531915           0.531915           0.531915         0.534353
#
#    std_test_score  rank_test_score
# 0        0.082762               17
# 1        0.082762               17
# 2        0.079551               20
# 3        0.048751                3
# 4        0.004223               41

# %%
score_df.nlargest(5,"mean_test_score")
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 30       0.005985      0.001221         0.002991    1.976862e-07
# 5        0.007730      0.004750         0.003990    1.728002e-03
# 3        0.006981      0.000997         0.004488    4.994892e-04
# 8        0.005235      0.000827         0.002744    4.325687e-04
# 13       0.007978      0.005230         0.002743    4.321899e-04
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 30         entropy               3                      5
# 5             gini               3                      5
# 3             gini               2                     50
# 8             gini               3                     50
# 13            gini               5                     50
#
#                                                params  split0_test_score  \
# 30  {'criterion': 'entropy', 'max_depth': 3, 'min_...           0.604167
# 5   {'criterion': 'gini', 'max_depth': 3, 'min_sam...           0.625000
# 3   {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.666667
# 8   {'criterion': 'gini', 'max_depth': 3, 'min_sam...           0.666667
# 13  {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.666667
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 30           0.765957           0.617021           0.680851         0.666999
# 5            0.744681           0.595745           0.659574         0.656250
# 3            0.680851           0.574468           0.702128         0.656028
# 8            0.680851           0.574468           0.702128         0.656028
# 13           0.680851           0.574468           0.702128         0.656028
#
#     std_test_score  rank_test_score
# 30        0.064090                1
# 5         0.055831                2
# 3         0.048751                3
# 8         0.048751                3
# 13        0.048751                3

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=42)

# %%
dt_best = grid_search.best_estimator_

# %%
evaluate_model(dt_best)
# Out:
# Train Accuracy : 0.7195767195767195
# Train Confusion Matrix:
# [[82 19]
#  [34 54]]
# --------------------------------------------------
# Test Accuracy : 0.6172839506172839
# Test Confusion Matrix:
# [[36 13]
#  [18 14]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, dt_best.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70        49
#            1       0.52      0.44      0.47        32
#
#     accuracy                           0.62        81
#    macro avg       0.59      0.59      0.59        81
# weighted avg       0.61      0.62      0.61        81

# %%
gph = get_dt_graph(dt_best)
Image(gph.create_png())

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(random_state=42, n_estimators=10, max_depth=3)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10, random_state=42)

# %%
rf.estimators_[0]
# Out:
# DecisionTreeClassifier(max_depth=3, max_features='sqrt',
#                        random_state=1608637542)

# %%
sample_tree = rf.estimators_[4]

# %%
gph = get_dt_graph(sample_tree)
Image(gph.create_png(), width=700, height=700)

# %%
gph = get_dt_graph(rf.estimators_[2])
Image(gph.create_png(), width=700, height=700)

# %%
evaluate_model(rf)
# Out:
# Train Accuracy : 0.7407407407407407
# Train Confusion Matrix:
# [[80 21]
#  [28 60]]
# --------------------------------------------------
# Test Accuracy : 0.6172839506172839
# Test Confusion Matrix:
# [[35 14]
#  [17 15]]

# %% [markdown]
# #### Grid search for hyper-parameter tuning

# %%
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
# Create the parameter grid based on the results of random search 
params = {
    'max_depth': [1, 2, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'max_features': [2,3,4],
    'n_estimators': [10, 30, 50, 100, 200]
}

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=classifier_rf, param_grid=params, 
                          cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
# %%time
grid_search.fit(X,y)
# Out:
# Fitting 4 folds for each of 375 candidates, totalling 1500 fits
# CPU times: total: 7.95 s
# Wall time: 1min 6s
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [1, 2, 5, 10, 20],
#                          'max_features': [2, 3, 4],
#                          'min_samples_leaf': [5, 10, 20, 50, 100],
#                          'n_estimators': [10, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
rf_best = grid_search.best_estimator_

# %%
rf_best
# Out:
# RandomForestClassifier(max_depth=5, max_features=3, min_samples_leaf=5,
#                        n_estimators=30, n_jobs=-1, random_state=42)

# %%
evaluate_model(rf_best)
# Out:
# Train Accuracy : 0.8042328042328042
# Train Confusion Matrix:
# [[87 14]
#  [23 65]]
# --------------------------------------------------
# Test Accuracy : 0.8024691358024691
# Test Confusion Matrix:
# [[42  7]
#  [ 9 23]]

# %%
sample_tree = rf_best.estimators_[0]

# %%
gph = get_dt_graph(sample_tree)
Image(gph.create_png())

# %%
gph = get_dt_graph(rf_best.estimators_[0])
Image(gph.create_png(), height=600, width=600)

# %%
gph = get_dt_graph(rf_best.estimators_[10])
Image(gph.create_png(), height=600, width=600)

# %% [markdown]
# ### Variable importance in RandomForest and Decision trees

# %%
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5, n_estimators=100, oob_score=True)

# %%
classifier_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
classifier_rf.feature_importances_
# Out:
# array([0.37539743, 0.13780788, 0.20834585, 0.27844883])

# %%
imp_df = pd.DataFrame({
    "Varname": X_train.columns,
    "Imp": classifier_rf.feature_importances_
})

# %%
imp_df.sort_values(by="Imp", ascending=False)
# Out:
#       Varname       Imp
# 0         age  0.375397
# 3  cholestrol  0.278449
# 2          BP  0.208346
# 1         sex  0.137808
