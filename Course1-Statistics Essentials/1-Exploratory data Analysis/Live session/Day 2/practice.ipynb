# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("titanic_dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#SibSp --> Siblings + Spouce
#parch --> Parent + Child
#Embarked --> Boarding Station

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
### Missing Value Check

# %%
#Percentage of missing values
#indentification of Missing Values
100*df.isnull().mean()
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
#Percentage of missing values
# generally > 40% of missing values do not consider remove column

# %%
df1=df.drop("Cabin",axis=1)
#axis = 1 as we are dropping the column axis =0 if want to drop row

# %%
100*df1.isnull().mean()
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Embarked        0.224467
# dtype: float64

# %%
med=df1["Age"].median()
df1["Age"]=df1["Age"].fillna(med)

# %%
100*df1.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.000000
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Embarked       0.224467
# dtype: float64

# %%
df2=df1[df1["Embarked"].notna()]
#removing embarked values is missing

# %%
100*df2.isnull().mean()
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %%
df2.shape
# Out:
# (889, 11)

# %%
##Univariate Analysis
# age / gender out of a population

#Bivariate

#average age gender wise analyzing 2 var

# Multivariate analyzing multiple variable 
#salary distribution with respect to age and gender

# %%
##Univariate Analysis

# %%
sns.countplot(x=df2["Sex"])
plt.show()

# %%
sns.histplot(x=df2["Age"])
plt.show()

# %%
df2["Age"].describe()
# Out:
# count    889.000000
# mean      29.315152
# std       12.984932
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(x=df2["Age"])
plt.show()
#Upper Whisker: Q1+1.5*(Q3-Q1)
#Lower Whisker: Q1-1.5*(Q3-Q1)

# %%
#Bivariate Analysis 
#Numaric vs Numaric Combination

# %%
sns.scatterplot(x=df2["Age"],y=df["Fare"])
plt.show()

# %%
### Numeric vs categorical
sns.boxplot(x=df2["Sex"],y=df2["Age"])
plt.show()

# %%
sns.boxplot(x=df2["Pclass"],y=df2["Age"])
plt.show()

# %%
###Multvatate Analysis

# %%
sns.heatmap(df2[["Age","Fare"]].corr(),annot=True)
plt.show()
